# %% [markdown]
# # The London Underground, Graphed

# %%
# %pip install folium
import pandas as pd
import networkx as nx
import requests
import folium
from collections import defaultdict
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.17.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.10/dist-packages (from folium) (2024.6.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.7.4)

# %% [markdown]
# ## Constructing Datasets
#
# Using the TfL API we construct tables of the London Underground lines, stations, and connections between those stations.
#
# These datasets are used to build a graph of the transport network for crime analysis.

# %%
tfl_api = "https://api.tfl.gov.uk"

# %% [markdown]
# ### Underground Lines

# %%
try:
    underground_lines = pd.read_csv("lines.csv")
except:
    line_data = requests.get(tfl_api + "/Line/Mode/tube").json()
    underground_lines = pd.DataFrame(line_data, columns=["id", "name"])
    underground_lines.to_csv("lines.csv", index=False)

underground_lines
# Out:
#                   id                name
# 0           bakerloo            Bakerloo
# 1            central             Central
# 2             circle              Circle
# 3           district            District
# 4   hammersmith-city  Hammersmith & City
# 5            jubilee             Jubilee
# 6       metropolitan        Metropolitan
# 7           northern            Northern
# 8         piccadilly          Piccadilly
# 9           victoria            Victoria
# 10     waterloo-city     Waterloo & City

# %% [markdown]
# ### Stations

# %%
try:
    stations = pd.read_csv("stations.csv", index_col="name")
except:
    station_data = set()

    for line in underground_lines.id:
        stop_points = requests.get(f"{tfl_api}/line/{line}/stoppoints").json()

        for point in stop_points:
            id = point["id"]
            name = point["commonName"].removesuffix(" Underground Station").removesuffix("-Underground")
            lat = point["lat"]
            lon = point["lon"]

            line_mode_tube = next(group for group in point["lineModeGroups"] if group["modeName"] == "tube")
            tube_lines = line_mode_tube["lineIdentifier"]

            station_data.add((id, name, lat, lon, ",".join(tube_lines)))

    stations = pd.DataFrame(station_data, columns=["id", "name", "latitude", "longitude", "lines"]).set_index("name").sort_values("name")
    stations.to_csv("stations.csv")

stations
# Out:
#                          id   latitude  longitude                      lines
# name
# Acton Town      940GZZLUACT  51.503057  -0.280462        district,piccadilly
# Aldgate         940GZZLUALD  51.514246  -0.075689        circle,metropolitan
# Aldgate East    940GZZLUADE  51.515037  -0.072384  district,hammersmith-city
# Alperton        940GZZLUALP  51.540627  -0.299610                 piccadilly
# Amersham        940GZZLUAMS  51.674126  -0.607714               metropolitan
# ...                     ...        ...        ...                        ...
# Wimbledon Park  940GZZLUWIP  51.434573  -0.199719                   district
# Wood Green      940GZZLUWOG  51.597479  -0.109886                 piccadilly
# Wood Lane       940GZZLUWLA  51.509669  -0.224530    circle,hammersmith-city
# Woodford        940GZZLUWOF  51.606899   0.033970                    central
# Woodside Park   940GZZLUWOP  51.618014  -0.185420                   northern
#
# [272 rows x 4 columns]

# %%
try:
    connections = pd.read_csv("connections.csv")
except:
    station_by_id = { row["id"]: station for station, row in stations.iterrows() }

    connection_data = list()

    for line in underground_lines.id:
        route = requests.get(f"{tfl_api}/line/{line}/Route/Sequence/all").json()

        for line_route in route["orderedLineRoutes"]:
            station_ids = line_route["naptanIds"]

            for source, dest in zip(station_ids, station_ids[1:]):
                station1, station2 = sorted((station_by_id[source], station_by_id[dest]))
                connection_data.append((station1, station2, line))

    connections = pd.DataFrame(connection_data, columns=["station1", "station2", "line"]).drop_duplicates(ignore_index=True)
    connections.to_csv("connections.csv", index=False)

connections
# Out:
#               station1             station2           line
# 0    Elephant & Castle        Lambeth North       bakerloo
# 1        Lambeth North             Waterloo       bakerloo
# 2           Embankment             Waterloo       bakerloo
# 3        Charing Cross           Embankment       bakerloo
# 4        Charing Cross    Piccadilly Circus       bakerloo
# ..                 ...                  ...            ...
# 372      Finsbury Park        Seven Sisters       victoria
# 373      Seven Sisters       Tottenham Hale       victoria
# 374    Blackhorse Road       Tottenham Hale       victoria
# 375    Blackhorse Road  Walthamstow Central       victoria
# 376               Bank             Waterloo  waterloo-city
#
# [377 rows x 3 columns]

# %% [markdown]
# ### Dealing with Paddington
#
# Since the crime data does not distinguish between Paddington and Paddington (H&C Line), we merge the stations in our graph

# %%
stations.loc["Paddington", "lines"] += ",hammersmith-city"
stations.drop("Paddington (H&C Line)", inplace=True)

connections.replace({"Paddington (H&C Line)": "Paddington"}, inplace=True)
connections.drop_duplicates(ignore_index=True, inplace=True)

# %%
stations_by_line = defaultdict(lambda: set())

for station, row in stations.iterrows():
    for line in row["lines"].split(","):
        stations_by_line[line].add(station)

# %% [markdown]
# ## Graphing the Underground Network

# %%
g = nx.MultiGraph()

for _, connection in connections.iterrows():
    g.add_edge(*connection)

for station, (id, latitude, longitude, lines) in stations.iterrows():
    g.nodes[station]["lines"] = lines.split(",")
    g.nodes[station]["latitude"] = latitude
    g.nodes[station]["longitude"] = longitude

# %% [markdown]
# Example: calculating the shortest path between any two stations

# %%
nx.shortest_path(g, "Victoria", "Camden Town")
# Out:
# ['Victoria',
#  'Green Park',
#  'Oxford Circus',
#  'Warren Street',
#  'Euston',
#  'Camden Town']

# %% [markdown]
# ## Adding Crime Data

# %%
with open("crimes.csv", "w") as f:
    response = requests.get("https://raw.githubusercontent.com/undevised/crime-on-the-underground/main/content/data/crimes.csv")
    f.write(response.content.decode("utf-8"))

crimes = pd.read_csv("crimes.csv", index_col="Unique ID", keep_default_na=False)

crimes["Lines"] = crimes.apply(lambda x: x["Train Operating Company"].replace(" & ", "-").replace(" and ", ",").lower(), axis=1)

crimes
# Out:
#             Category Start Location End Location Reporting Location  \
# Unique ID
# 126452       Station     Acton Town   Acton Town         Acton Town
# 126453       Station     Acton Town   Acton Town         Acton Town
# 137061     On Train        Alperton   Acton Town         Acton Town
# 99258      On Train    Barons Court   Acton Town         Acton Town
# 114712     On Train    Barons Court   Acton Town         Acton Town
# ...              ...            ...          ...                ...
# 182258       Station
# 182865     On Train
# 184090       Station
# 184078       Station
# 182855     On Train
#
#           Train Operating Company       Lines
# Unique ID
# 126452                 Piccadilly  piccadilly
# 126453                 Piccadilly  piccadilly
# 137061                 Piccadilly  piccadilly
# 99258                  Piccadilly  piccadilly
# 114712                 Piccadilly  piccadilly
# ...                           ...         ...
# 182258                    Central     central
# 182865                    Central     central
# 184090                   District    district
# 184078                   Northern    northern
# 182855                 Piccadilly  piccadilly
#
# [27091 rows x 6 columns]

# %%
# initialse crime records
nx.set_node_attributes(g, 0, "crimes")
nx.set_edge_attributes(g, 0, "crimes")

def record_station_crime_at(graph, station):
    graph.nodes[station]["crimes"] += 1

def record_station_crime_on_line(graph, line, weight):
    stations_on_line = stations_by_line[line]

    for station in stations_on_line:
        graph.nodes[station]["crimes"] += weight / len(stations_on_line)

def record_train_crime_between(graph, start_station, end_station):
    path = nx.shortest_path(graph, start_station, end_station)

    path_edges = graph.subgraph(path).edges(keys=True)

    for edge in path_edges:
        graph.edges[edge]["crimes"] += 1 / len(path_edges)

def record_train_crime_on_line(graph, line, weight):
    edges = nx.subgraph_view(
        g,
        filter_node=lambda node: node in stations_by_line[line],
        filter_edge=lambda a, b, key: key == line
    ).edges(keys=True)

    for edge in edges:
        graph.edges[edge]["crimes"] += weight / len(edges)

# process each row of crime data, adding to graph
for id, crime in crimes.iterrows():
    category = crime["Category"].strip()
    start = crime["Start Location"]
    reporting = crime["Reporting Location"]
    lines = crime["Lines"].split(",")

    if category == "Station":

        # if reporting location is known, record crime at specified station
        if reporting:
            record_station_crime_at(g, reporting)

        # otherwise, distribute crime across all stations on the specified line(s)
        else:
            for line in lines:
                record_station_crime_on_line(g, line, 1 / len(lines))

    elif category == "On Train":

        # if start and reporting location are known, record crime on path between stations
        if start and reporting:
            record_train_crime_between(g, start, reporting)

        # otherwise, distribute crime across all segments of the specified line(s)
        else:
            for line in lines:
                record_train_crime_on_line(g, line, 1 / len(lines))

    else:
        print(f"WARNING: unexpected category '{category}'")

# %% [markdown]
# ## Adding Passenger Data

# %%
with open("passengers.csv", "w") as f:
    response = requests.get("https://raw.githubusercontent.com/undevised/crime-on-the-underground/main/content/data/passengers.csv")
    f.write(response.content.decode("utf-8"))

passengers = pd.read_csv("passengers.csv", index_col="Station")

passengers
# Out:
#                 Entry/Exit
# Station
# Acton Town        13701833
# Aldgate           17129121
# Aldgate East      24881038
# Alperton           6564904
# Amersham           4446831
# ...                    ...
# Wimbledon Park     4838778
# Wood Green        25259999
# Wood Lane         11289998
# Woodford          11980768
# Woodside Park      5888045
#
# [271 rows x 1 columns]

# %%
# initialse passengers numbers
nx.set_node_attributes(g, 0, "passengers")
nx.set_edge_attributes(g, 0, "passengers")

def add_passengers(graph, station, volume):
    # record station passenger volume
    graph.nodes[station]["passengers"] = volume

    # distribute passenger volume across all lines at this station
    edges = g.edges(station, keys=True)
    for edge in edges:
        graph.edges[edge]["passengers"] += volume / len(edges)

# add passenger data to stations & line segments
for station, row in passengers.iterrows():
    add_passengers(g, station, row["Entry/Exit"] / 2)

# %% [markdown]
# ### Normalising Results

# %%
# noramlise station crimes by passenger figures
for station, data in g.nodes(data=True):
    g.nodes[station]["crimes_per_million_passengers"] = 1_000_000 * data["crimes"] / data["passengers"]

# normalise segment crimes by passenger figures
for station1, station2, line, data in g.edges(keys=True, data=True):
    g.edges[(station1, station2, line)]["crimes_per_million_passengers"] = 1_000_000 * data["crimes"] / data["passengers"]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Station Crime

# %%
station_crime = pd.DataFrame(index=g.nodes)
station_crime["crimes"] = nx.get_node_attributes(g, "crimes")
station_crime["passengers"] = nx.get_node_attributes(g, "passengers")
station_crime["crimes_per_million_passengers"] = 1_000_000 * station_crime["crimes"] / station_crime["passengers"]

# %%
station_crime.sort_values("crimes", ascending=False)
# Out:
#                               crimes  passengers  \
# Oxford Circus             605.141939  70276328.0
# King's Cross St. Pancras  529.606796  88994137.5
# Leicester Square          493.229681  38267555.0
# Tottenham Court Road      470.520016  57321470.0
# Finsbury Park             427.931604  23862703.0
# ...                              ...         ...
# Northwood Hills             0.470588   1850867.0
# South Woodford              0.346939   5361054.5
# Grange Hill                 0.346939    510934.5
# Battersea Power Station     0.173077   7368741.0
# Heathrow Terminal 4         0.056604    820937.0
#
#                           crimes_per_million_passengers
# Oxford Circus                                  8.610893
# King's Cross St. Pancras                       5.951030
# Leicester Square                              12.888978
# Tottenham Court Road                           8.208443
# Finsbury Park                                 17.933073
# ...                                                 ...
# Northwood Hills                                0.254253
# South Woodford                                 0.064715
# Grange Hill                                    0.679028
# Battersea Power Station                        0.023488
# Heathrow Terminal 4                            0.068950
#
# [271 rows x 3 columns]

# %%
station_crime.sort_values("crimes_per_million_passengers", ascending=False)
# Out:
#                              crimes  passengers  crimes_per_million_passengers
# West Ham                 182.426501   6672711.5                      27.339186
# Finsbury Park            427.931604  23862703.0                      17.933073
# Upton Park               174.167241  11241611.5                      15.493085
# East Ham                 188.167241  14026321.0                      13.415296
# Leicester Square         493.229681  38267555.0                      12.888978
# ...                             ...         ...                            ...
# Richmond                   4.150000  13835305.5                       0.299957
# Northwood Hills            0.470588   1850867.0                       0.254253
# Heathrow Terminal 4        0.056604    820937.0                       0.068950
# South Woodford             0.346939   5361054.5                       0.064715
# Battersea Power Station    0.173077   7368741.0                       0.023488
#
# [271 rows x 3 columns]

# %% [markdown]
# ### Train Crime

# %%
train_crime = pd.DataFrame(index=g.edges(keys=True))
train_crime["crimes"] = nx.get_edge_attributes(g, "crimes")
train_crime["passengers"] = nx.get_edge_attributes(g, "passengers")
train_crime["crimes_per_million_passengers"] = 1_000_000 * train_crime["crimes"] / train_crime["passengers"]

# %%
train_crime.sort_values("crimes", ascending=False)
# Out:
#                                                               crimes  \
# Oxford Circus            Green Park             victoria  220.015298
# Victoria                 Green Park             victoria  212.007498
# King's Cross St. Pancras Highbury & Islington   victoria  186.764068
# Oxford Circus            Warren Street          victoria  186.165003
# Waterloo                 Westminster            jubilee   186.153148
# ...                                                              ...
# Cannon Street            Monument               circle      5.155800
# Blackfriars              Mansion House          circle      5.143708
# Goldhawk Road            Hammersmith (H&C Line) circle      4.923637
# Shepherd's Bush Market   Goldhawk Road          circle      4.756030
# Mansion House            Cannon Street          circle      4.311447
#
#                                                             passengers  \
# Oxford Circus            Green Park             victoria  1.803596e+07
# Victoria                 Green Park             victoria  1.914742e+07
# King's Cross St. Pancras Highbury & Islington   victoria  1.716062e+07
# Oxford Circus            Warren Street          victoria  1.584515e+07
# Waterloo                 Westminster            jubilee   1.406152e+07
# ...                                                                ...
# Cannon Street            Monument               circle    3.970608e+06
# Blackfriars              Mansion House          circle    4.179397e+06
# Goldhawk Road            Hammersmith (H&C Line) circle    5.695222e+06
# Shepherd's Bush Market   Goldhawk Road          circle    1.514957e+06
# Mansion House            Cannon Street          circle    2.500027e+06
#
#                                                           crimes_per_million_passengers
# Oxford Circus            Green Park             victoria                      12.198702
# Victoria                 Green Park             victoria                      11.072380
# King's Cross St. Pancras Highbury & Islington   victoria                      10.883292
# Oxford Circus            Warren Street          victoria                      11.749020
# Waterloo                 Westminster            jubilee                       13.238477
# ...                                                                                 ...
# Cannon Street            Monument               circle                         1.298491
# Blackfriars              Mansion House          circle                         1.230730
# Goldhawk Road            Hammersmith (H&C Line) circle                         0.864521
# Shepherd's Bush Market   Goldhawk Road          circle                         3.139384
# Mansion House            Cannon Street          circle                         1.724560
#
# [376 rows x 3 columns]

# %%
train_crime.sort_values("crimes_per_million_passengers", ascending=False)
# Out:
#                                                         crimes    passengers  \
# Chigwell         Roding Valley          central      15.748210  3.151400e+05
# Grange Hill      Chigwell               central      15.748210  4.601320e+05
# Ickenham         Hillingdon             piccadilly   13.963237  7.315990e+05
# Warren Street    Euston                 victoria    181.842772  9.979945e+06
# Ruislip          Ickenham               piccadilly   13.173382  7.680816e+05
# ...                                                        ...           ...
# Liverpool Street Aldgate                circle        9.912169  1.122723e+07
# Goldhawk Road    Hammersmith (H&C Line) circle        4.923637  5.695222e+06
# Monument         Tower Hill             circle        6.193799  7.777753e+06
# Kew Gardens      Richmond               district     11.321123  1.625000e+07
# Wimbledon Park   Wimbledon              district     10.871301  2.195868e+07
#
#                                                     crimes_per_million_passengers
# Chigwell         Roding Valley          central                         49.972107
# Grange Hill      Chigwell               central                         34.225418
# Ickenham         Hillingdon             piccadilly                      19.085917
# Warren Street    Euston                 victoria                        18.220818
# Ruislip          Ickenham               piccadilly                      17.151019
# ...                                                                           ...
# Liverpool Street Aldgate                circle                           0.882868
# Goldhawk Road    Hammersmith (H&C Line) circle                           0.864521
# Monument         Tower Hill             circle                           0.796348
# Kew Gardens      Richmond               district                         0.696684
# Wimbledon Park   Wimbledon              district                         0.495080
#
# [376 rows x 3 columns]

# %% [markdown]
# ### Tube Lines

# %%
line_crime = pd.DataFrame(columns=["train_crimes", "station_crimes", "total_crimes", "passengers", "crimes_per_million_passengers"])

for line in underground_lines.id:
    subgraph = nx.subgraph_view(
        g,
        filter_node=lambda node: node in stations_by_line[line],
        filter_edge=lambda a, b, key: key == line
    )

    train_crimes = sum(nx.get_edge_attributes(subgraph, "crimes").values())
    station_crimes = sum(data["crimes"] / len(data["lines"]) for station, data in subgraph.nodes(data=True))

    train_passengers = sum(nx.get_edge_attributes(subgraph, "passengers").values())
    station_passengers = sum(data["passengers"] / len(data["lines"]) for station, data in subgraph.nodes(data=True))

    line_crime.loc[line] = (
        train_crimes,
        station_crimes,
        train_crimes + station_crimes,
        train_passengers + station_passengers,
        1_000_000 * (train_crimes + station_crimes) / (train_passengers + station_passengers)
    )

line_crime.sum()
# Out:
# train_crimes                     1.332800e+04
# station_crimes                   1.364900e+04
# total_crimes                     2.697700e+04
# passengers                       5.604631e+09
# crimes_per_million_passengers    5.174967e+01
# dtype: float64

# %%
line_crime.sort_values("total_crimes", ascending=False)
# Out:
#                   train_crimes  station_crimes  total_crimes    passengers  \
# northern           2208.056244     2174.435236   4382.491480  9.542868e+08
# central            2311.382530     1820.705109   4132.087638  7.529832e+08
# victoria           2119.833290     1962.763079   4082.596369  5.391972e+08
# jubilee            1948.733063     1625.497616   3574.230679  6.720491e+08
# piccadilly         1531.447995     1766.692366   3298.140361  6.217883e+08
# district           1016.718102     1258.728032   2275.446134  7.141078e+08
# bakerloo            488.858107      850.299440   1339.157547  3.268991e+08
# hammersmith-city    444.840439      814.366102   1259.206541  2.951320e+08
# circle              543.523433      698.233440   1241.756872  4.188539e+08
# metropolitan        617.528760      576.351491   1193.880251  2.648755e+08
# waterloo-city        97.078038      100.928089    198.006127  4.445800e+07
#
#                   crimes_per_million_passengers
# northern                               4.592426
# central                                5.487623
# victoria                               7.571620
# jubilee                                5.318407
# piccadilly                             5.304282
# district                               3.186418
# bakerloo                               4.096547
# hammersmith-city                       4.266588
# circle                                 2.964654
# metropolitan                           4.507326
# waterloo-city                          4.453780

# %%
line_crime.sort_values("crimes_per_million_passengers", ascending=False)
# Out:
#                   train_crimes  station_crimes  total_crimes    passengers  \
# victoria           2119.833290     1962.763079   4082.596369  5.391972e+08
# central            2311.382530     1820.705109   4132.087638  7.529832e+08
# jubilee            1948.733063     1625.497616   3574.230679  6.720491e+08
# piccadilly         1531.447995     1766.692366   3298.140361  6.217883e+08
# northern           2208.056244     2174.435236   4382.491480  9.542868e+08
# metropolitan        617.528760      576.351491   1193.880251  2.648755e+08
# waterloo-city        97.078038      100.928089    198.006127  4.445800e+07
# hammersmith-city    444.840439      814.366102   1259.206541  2.951320e+08
# bakerloo            488.858107      850.299440   1339.157547  3.268991e+08
# district           1016.718102     1258.728032   2275.446134  7.141078e+08
# circle              543.523433      698.233440   1241.756872  4.188539e+08
#
#                   crimes_per_million_passengers
# victoria                               7.571620
# central                                5.487623
# jubilee                                5.318407
# piccadilly                             5.304282
# northern                               4.592426
# metropolitan                           4.507326
# waterloo-city                          4.453780
# hammersmith-city                       4.266588
# bakerloo                               4.096547
# district                               3.186418
# circle                                 2.964654

# %%
from pathlib import Path

Path("results").mkdir(exist_ok=True)

station_crime.sort_values("crimes", ascending=False).to_csv("results/station_crime.csv", )
train_crime.sort_values("crimes", ascending=False).to_csv("results/train_crime.csv")
line_crime.sort_values("total_crimes", ascending=False).to_csv("results/line_crime.csv")

# %% [markdown]
# ### Visualising Results

# %%
# source: https://content.tfl.gov.uk/tfl-colour-standard-issue-08.pdf
line_colours = {
    "central": (225, 37, 27),
    "circle": (255, 205, 0),
    "bakerloo": (166, 90, 42),
    "district": (0, 121, 52),
    "jubilee": (123, 134, 140),
    "hammersmith-city": (236, 155, 173),
    "northern": (0, 0, 0),
    "metropolitan": (135, 15, 84),
    "piccadilly": (0, 15, 159),
    "victoria": (0, 160, 223),
    "waterloo-city": (107, 205, 178)
}

# %% [markdown]
# The map below shows total and normalised crimes across each London Underground line.

# %%
map = folium.Map(
    location=(51.5072, -0.1276),
    tiles="cartodb positron",
    zoom_start=11,
)

feature_total = folium.FeatureGroup(name="Total Crimes",).add_to(map)
feature_normalised = folium.FeatureGroup(name="Crimes per million", show=False).add_to(map)

for src, dest, line, data in g.edges(keys=True, data=True):
    pos1 = [g.nodes[src]["latitude"], g.nodes[src]["longitude"]]
    pos2 = [g.nodes[dest]["latitude"], g.nodes[dest]["longitude"]]

    folium.PolyLine(
        locations=[pos1, pos2],
        tooltip=f"{line}: {line_crime['total_crimes'][line]:.1f} total crimes",
        color="#%02x%02x%02x" % line_colours[line],
        dashArray=f"4 {len(underground_lines)}",
        dashOffset=str(list(line_colours.keys()).index(line)),
        weight=line_crime["total_crimes"][line] / line_crime["total_crimes"].quantile(0.01)
    ).add_to(feature_total)

    folium.PolyLine(
        locations=[pos1, pos2],
        tooltip=f"{line}: {line_crime['crimes_per_million_passengers'][line]:.1f} crimes per million passengers",
        color="#%02x%02x%02x" % line_colours[line],
        dashArray=f"4 {len(underground_lines)}",
        dashOffset=str(list(line_colours.keys()).index(line)),
        weight=line_crime["crimes_per_million_passengers"][line]
    ).add_to(feature_normalised)

folium.LayerControl(collapsed=False).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7f6497981624392a33f0bd5767994bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7f6497981624392a33f0bd5767994bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7f6497981624392a33f0bd5767994bb = L.map(
#                 &quot;map_d7f6497981624392a33f0bd5767994bb&quot;,
#                 {
#                     center: [51.5072, -0.1276],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43008862586c5d0c97ca32b949a71ce4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_43008862586c5d0c97ca32b949a71ce4.addTo(map_d7f6497981624392a33f0bd5767994bb);
#
#
#             var feature_group_d9c8ae0e147accca08f455ffd7860a08 = L.featureGroup(
#                 {}
#             );
#
#
#             var poly_line_6cb4798a2e299f8a44e592b56b021bbf = L.polyline(
#                 [[51.494536, -0.100606], [51.498808, -0.112315]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#a65a2a&quot;, &quot;dashArray&quot;: &quot;4 11&quot;, &quot;dashOffset&quot;: &quot;2&quot;, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#a65a2a&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4.49995503327009}
#             ).addTo(feature_group_d9c8ae0e147accca08f455ffd7860a08);
#
#
#             poly_line_6cb4798a2e299f8a44e592b56b021bbf.bindTooltip(
#                 `&lt;div&gt;
#                      bakerloo: 1339.2 total crimes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_5e02475c6466e1aab38c4988aa59ed8b = L.polyline(
#                 [[51.494536, -0.100606], [51.501199, -0.09337]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: &quot;4 11&quot;, &quot;dashOffset&quot;: &quot;6&quot;, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 14.726433524282667}
#             ).addTo(feature_group_d9c8ae0e147accca08f455ffd7860a08);
#
#
#             poly_line_5e02475c6466e1aab38c4988aa59ed8b.bindTooltip(
#                 `&lt;div&gt;
#                      northern: 4382.5 total crimes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_f6a2d1a7dd8c99fa839626ad07622620 = L.polyline(
#                 [[51.494536, -0.100606], [51.488337, -0.105963]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#000000&quot;, &quot;dashArray&quot;: &quot;4 11&quot;, &quot;dashOffset&quot;: &quot;6&quot;, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#000000&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 14.726433524282667}
#             ).addTo(feature_group_d9c8ae0e147accca08f455ffd7860a08);
#
#
#             poly_line_f6a2d1a7dd8c99fa839626ad07622620.bindTooltip(
#                 `&lt;div&gt;
#                      northern: 4382.5 total crimes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_c4b0ce5bd45cf9d1b060cd1ab818a354 = L.polyline(
#                 [[51.498808, -0.112315], [51.503299, -0.11478]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#a65a2a&quot;, &quot;dashArray&quot;: &quot;4 11&quot;, &quot;dashOffset&quot;: &quot;2&quot;, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#a65a2a&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 4.49995503327009}
#             ).addTo(feature_group_d9c8ae0e147accca08f455ffd7860a08);
#
#
#             poly_line_c4b0ce5bd45cf9d1b060cd1ab818a354.bindTooltip(

# %% [markdown]
# The map below shows total crimes across all stations and segments of the London Underground network.

# %%
map = folium.Map(
    location=(51.5072, -0.1276),
    tiles="cartodb positron",
    zoom_start=11,
)

feature_at_station = folium.FeatureGroup(name="At-station crime",).add_to(map)
feature_on_train = folium.FeatureGroup(name="On-train crime").add_to(map)

for node, data in g.nodes(data=True):
    value = data["crimes"]

    folium.CircleMarker(
        location=[data["latitude"], data["longitude"]],
        radius=value / 20,
        tooltip=node,
        popup=f"{value:.1f} total crimes",
        fill=True,
        weight=1,
        color="darkred"
    ).add_to(feature_at_station)

for src, dest, line, data in g.edges(keys=True, data=True):
    value = data["crimes"]

    pos1 = [g.nodes[src]["latitude"], g.nodes[src]["longitude"]]
    pos2 = [g.nodes[dest]["latitude"], g.nodes[dest]["longitude"]]

    folium.PolyLine(
        locations=[pos1, pos2],
        tooltip=f"{src} - {dest} ({line})",
        popup=f"{value:.1f} total crimes",
        color="#%02x%02x%02x" % line_colours[line],
        dashArray=f"4 {len(underground_lines)}",
        dashOffset=str(list(line_colours.keys()).index(line)),
        lineCap="square",
        weight=value / 20,
    ).add_to(feature_on_train)

folium.LayerControl(collapsed=False).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bc71ff04be82d3b578c128a03f118f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bc71ff04be82d3b578c128a03f118f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bc71ff04be82d3b578c128a03f118f9 = L.map(
#                 &quot;map_8bc71ff04be82d3b578c128a03f118f9&quot;,
#                 {
#                     center: [51.5072, -0.1276],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2e093a11e2f989a877bff45cfcf96aa = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c2e093a11e2f989a877bff45cfcf96aa.addTo(map_8bc71ff04be82d3b578c128a03f118f9);
#
#
#             var feature_group_0c813b2e482b06b50ba2403a3f65b91f = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_a6b7a7bbadad6b248e9ab95813c214f8 = L.circleMarker(
#                 [51.494536, -0.100606],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3.804653846153863, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(feature_group_0c813b2e482b06b50ba2403a3f65b91f);
#
#
#         var popup_b6647d837d4d794422149272675827d7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2905ca230b94d383ce450c1032fa310d = $(`&lt;div id=&quot;html_2905ca230b94d383ce450c1032fa310d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;76.1 total crimes&lt;/div&gt;`)[0];
#                 popup_b6647d837d4d794422149272675827d7.setContent(html_2905ca230b94d383ce450c1032fa310d);
#
#
#
#         circle_marker_a6b7a7bbadad6b248e9ab95813c214f8.bindPopup(popup_b6647d837d4d794422149272675827d7)
#         ;
#
#
#
#
#             circle_marker_a6b7a7bbadad6b248e9ab95813c214f8.bindTooltip(
#                 `&lt;div&gt;
#                      Elephant &amp; Castle
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_da4a02b3667cfba5a2ed7f8f9a5e0a50 = L.circleMarker(
#                 [51.498808, -0.112315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.49599999999999794, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(feature_group_0c813b2e482b06b50ba2403a3f65b91f);
#
#
#         var popup_4cea3dc3625fcfc18e02f1998de37c31 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50df590f0879fe70f7650fd5bb466b07 = $(`&lt;div id=&quot;html_50df590f0879fe70f7650fd5bb466b07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;9.9 total crimes&lt;/div&gt;`)[0];
#                 popup_4cea3dc3625fcfc18e02f1998de37c31.setContent(html_50df590f0879fe70f7650fd5bb466b07);
#
#
#
#         circle_marker_da4a02b3667cfba5a2ed7f8f9a5e0a50.bindPopup(popup_4cea3dc3625fcfc18e02f1998de37c31)
#         ;
#
#
#
#
#             circle_marker_da4a02b3667cfba5a2ed7f8f9a5e0a50.bindTooltip(
#                 `&lt;div&gt;
#                      Lambeth North
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_6332c47e74e5acf198de9cb7f0e4ce90 = L.circleMarker(
#                 [51.503299, -0.11478],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 9.617616809116793, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(feature_group_0c813b2e482b06b50ba2403a3f65b91f);
#
#
#         var popup_55e2c0788445d2dab97c5ee7c1133f81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});

# %% [markdown]
# The map below shows crimes per million passengers across all stations and segments of the London Underground network.

# %%
map = folium.Map(
    location=(51.5072, -0.1276),
    tiles="cartodb positron",
    zoom_start=11,
)

feature_at_station = folium.FeatureGroup(name="At-station crime",).add_to(map)
feature_on_train = folium.FeatureGroup(name="On-train crime").add_to(map)

for node, data in g.nodes(data=True):
    value = data["crimes_per_million_passengers"]

    folium.CircleMarker(
        location=[data["latitude"], data["longitude"]],
        radius=value,
        tooltip=node,
        popup=f"{value:.1f} crimes per million passengers",
        fill=True,
        weight=1,
        color="darkred"
    ).add_to(feature_at_station)

for src, dest, line, data in g.edges(keys=True, data=True):
    value = data["crimes_per_million_passengers"]

    pos1 = [g.nodes[src]["latitude"], g.nodes[src]["longitude"]]
    pos2 = [g.nodes[dest]["latitude"], g.nodes[dest]["longitude"]]

    folium.PolyLine(
        locations=[pos1, pos2],
        tooltip=f"{src} - {dest} ({line})",
        popup=f"{value:.1f} crimes per million passengers",
        color="#%02x%02x%02x" % line_colours[line],
        dashArray=f"4 {len(underground_lines)}",
        dashOffset=str(list(line_colours.keys()).index(line)),
        lineCap="square",
        weight=value / 2,
    ).add_to(feature_on_train)

folium.LayerControl(collapsed=False).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb1e1d1f5bab9f86837eb3948dbd6ab1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb1e1d1f5bab9f86837eb3948dbd6ab1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb1e1d1f5bab9f86837eb3948dbd6ab1 = L.map(
#                 &quot;map_cb1e1d1f5bab9f86837eb3948dbd6ab1&quot;,
#                 {
#                     center: [51.5072, -0.1276],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b51d1ab21f99306808eae86003b29996 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b51d1ab21f99306808eae86003b29996.addTo(map_cb1e1d1f5bab9f86837eb3948dbd6ab1);
#
#
#             var feature_group_9484455158f02040d241ab13725356d3 = L.featureGroup(
#                 {}
#             );
#
#
#             var circle_marker_c3e6065a3a9a5d41eb1bbe9e28b3dc5b = L.circleMarker(
#                 [51.494536, -0.100606],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 4.538046929766366, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(feature_group_9484455158f02040d241ab13725356d3);
#
#
#         var popup_1197a257c143c516d813a823a32d847b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f4c979602afbc411fe6da18961230af = $(`&lt;div id=&quot;html_0f4c979602afbc411fe6da18961230af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;4.5 crimes per million passengers&lt;/div&gt;`)[0];
#                 popup_1197a257c143c516d813a823a32d847b.setContent(html_0f4c979602afbc411fe6da18961230af);
#
#
#
#         circle_marker_c3e6065a3a9a5d41eb1bbe9e28b3dc5b.bindPopup(popup_1197a257c143c516d813a823a32d847b)
#         ;
#
#
#
#
#             circle_marker_c3e6065a3a9a5d41eb1bbe9e28b3dc5b.bindTooltip(
#                 `&lt;div&gt;
#                      Elephant &amp; Castle
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_07fc8662652b8f3f1fec5078f47e91d5 = L.circleMarker(
#                 [51.498808, -0.112315],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.945984833523632, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(feature_group_9484455158f02040d241ab13725356d3);
#
#
#         var popup_4a33b7da464705314264a6151bbe48e2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08ddaeb32189054b0176f3e62b0b6063 = $(`&lt;div id=&quot;html_08ddaeb32189054b0176f3e62b0b6063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2.9 crimes per million passengers&lt;/div&gt;`)[0];
#                 popup_4a33b7da464705314264a6151bbe48e2.setContent(html_08ddaeb32189054b0176f3e62b0b6063);
#
#
#
#         circle_marker_07fc8662652b8f3f1fec5078f47e91d5.bindPopup(popup_4a33b7da464705314264a6151bbe48e2)
#         ;
#
#
#
#
#             circle_marker_07fc8662652b8f3f1fec5078f47e91d5.bindTooltip(
#                 `&lt;div&gt;
#                      Lambeth North
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_marker_af567bdd5affaae743d4df7b04e7a999 = L.circleMarker(
#                 [51.503299, -0.11478],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;darkred&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;darkred&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2.7155191812653934, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(feature_group_9484455158f02040d241ab13725356d3);
#
#
#         var popup_963fcf001b7649171337ab8178397340 = L.popup({&quot;maxWidth&quot;: &quot;100%&qu
